# %%
import os
import shutil

# %%
data_dir = "/home/dylan/Desktop/data_science_work/UTKface_inthewild/UTKface_inthewild/"
#print(os.listdir(data_dir))

with open("/home/dylan/Desktop/data_science_work/UTKface_inthewild/humans_annotations.txt", "r") as f:
    for line in f:
        line = line.strip("\n")
        line_split = line.split(".")
        image_file = line_split[0]+".jpg"
        shutil.copy(data_dir+line, "/home/dylan/Desktop/data_science_work/datasets/humans/annotations/")
        shutil.copy(data_dir+image_file, "/home/dylan/Desktop/data_science_work/datasets/humans/images/")
        print(line)
        print(image_file)
# Out:
# 100_0_0_20170112213500903.txt
# 100_0_0_20170112213500903.jpg
# 100_0_0_20170112215240346.txt
# 100_0_0_20170112215240346.jpg
# 10_0_0_20161220222308131.txt
# 10_0_0_20161220222308131.jpg
# 10_0_0_20170103200329407.txt
# 10_0_0_20170103200329407.jpg
# 10_0_0_20170103200522151.txt
# 10_0_0_20170103200522151.jpg
# 10_0_0_20170103233459275.txt
# 10_0_0_20170103233459275.jpg
# 10_0_0_20170104013211746.txt
# 10_0_0_20170104013211746.jpg
# 10_0_0_20170110215927291.txt
# 10_0_0_20170110215927291.jpg
# 10_0_0_20170110220033115.txt
# 10_0_0_20170110220033115.jpg
# 10_0_0_20170110220111082.txt
# 10_0_0_20170110220111082.jpg
# 10_0_0_20170110220235233.txt
# 10_0_0_20170110220235233.jpg
# 10_0_0_20170110220251986.txt
# 10_0_0_20170110220251986.jpg
# 10_0_0_20170110220255346.txt
# 10_0_0_20170110220255346.jpg
# 10_0_0_20170110220316298.txt
# 10_0_0_20170110220316298.jpg
# 10_0_0_20170110220403810.txt
# 10_0_0_20170110220403810.jpg
# 10_0_0_20170110220447314.txt
# 10_0_0_20170110220447314.jpg
# ...
